# %% [markdown]
# <a href="https://colab.research.google.com/github/aceholland/Audio-Emotion-Detector/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
DATA_DIR = "/content"

# %%
emotion_map = {
    'a': 'anger', 'd': 'disgust', 'f': 'fear',
    'h': 'happiness', 'n': 'neutral', 'sa': 'sadness', 'su': 'surprise'
}

# %%
def get_emotion_from_filename(fname):
    code = fname.split('_')[1][:-6]
    code = ''.join([c for c in code if not c.isdigit()])
    return emotion_map.get(code, None)

# %%
wav_files = [f for f in os.listdir(DATA_DIR) if f.endswith(".wav")]
labels = [get_emotion_from_filename(f) for f in wav_files]

# %%
print("Total clips:", len(wav_files))
print("Clips per emotion:", Counter(labels))
# Out:
# Total clips: 480
# Clips per emotion: Counter({'neutral': 120, 'fear': 60, 'disgust': 60, 'sadness': 60, 'anger': 60, 'happiness': 60, 'surprise': 60})

# %%
plt.figure(figsize=(8, 4))
plt.bar(Counter(labels).keys(), Counter(labels).values())
plt.title("Number of clips per emotion")
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.show()

# %%
sample_file = os.path.join(DATA_DIR, wav_files[0])
y, sr = librosa.load(sample_file, sr=None)

# %%
plt.figure(figsize=(10, 3))
librosa.display.waveshow(y, sr=sr)
plt.title(f"Waveform example: {wav_files[0]} ({labels[0]})")
plt.show()

# %%
mfcc_example = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfcc_example, x_axis='time')
plt.colorbar()
plt.title(f"MFCC example: {wav_files[0]} ({labels[0]})")
plt.show()

# %%
def extract_features(file_path, n_mfcc=40):
    y, sr = librosa.load(file_path, sr=None)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return np.mean(mfcc.T, axis=0)

# %%
X, y_labels = [], []
for fname in wav_files:
    emotion = get_emotion_from_filename(fname)
    if emotion:
        X.append(extract_features(os.path.join(DATA_DIR, fname)))
        y_labels.append(emotion)

# %%
X = np.array(X)
print("Feature matrix shape:", X.shape)
# Out:
# Feature matrix shape: (480, 40)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y_labels)
num_classes = len(le.classes_)
print("Classes:", list(le.classes_))
# Out:
# Classes: [np.str_('anger'), np.str_('disgust'), np.str_('fear'), np.str_('happiness'), np.str_('neutral'), np.str_('sadness'), np.str_('surprise')]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)
print("Train size:", X_train.shape[0], "| Test size:", X_test.shape[0])
# Out:
# Train size: 384 | Test size: 96

# %%
model = models.Sequential([
    layers.Input(shape=(X.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,959 (54.53 KB)
#  Trainable params: 13,959 (54.53 KB)
# ...

# %%
history = model.fit(
    X_train, y_train,
    epochs=50, batch_size=16,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2083 - loss: 21.8720 - val_accuracy: 0.2708 - val_loss: 9.7263
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1667 - loss: 15.9315 - val_accuracy: 0.2917 - val_loss: 10.2389
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1927 - loss: 11.3647 - val_accuracy: 0.3333 - val_loss: 4.3568
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1719 - loss: 9.9042 - val_accuracy: 0.3229 - val_loss: 2.8188
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2161 - loss: 7.4106 - val_accuracy: 0.3333 - val_loss: 2.7420
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2344 - loss: 6.0749 - val_accuracy: 0.3229 - val_loss: 4.0039
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2578 - loss: 5.3383 - val_accuracy: 0.3438 - val_loss: 3.0592
# Epoch 8/50
# ...

# %%
plt.figure(figsize=(10, 4))
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title("Accuracy over epochs")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"\nFinal Test Accuracy: {test_acc:.2%}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6146 - loss: 0.8914
#
# Final Test Accuracy: 61.46%

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.64      0.75      0.69        12
#      disgust       0.80      0.33      0.47        12
#         fear       0.42      0.42      0.42        12
#    happiness       0.64      0.58      0.61        12
#      neutral       0.65      0.83      0.73        24
#      sadness       0.64      0.58      0.61        12
#     surprise       0.58      0.58      0.58        12
#
#     accuracy                           0.61        96
#    macro avg       0.62      0.58      0.59        96
# weighted avg       0.63      0.61      0.60        96

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(7, 6))
plt.imshow(cm, cmap='Blues')
plt.xticks(range(num_classes), le.classes_, rotation=45)
plt.yticks(range(num_classes), le.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.colorbar()
plt.show()
